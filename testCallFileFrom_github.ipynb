# %%
#test Call File จาก github

# %%
url = 'https://raw.githubusercontent.com/tapattan/labPython/main/set50_oct2021.csv'

# %%
import pandas as pd
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
df = pd.read_csv(url, error_bad_lines=False)
df
# Out:
#     Unnamed: 0  symbol
# 0            0  ADVANC
# 1            1     AOT
# 2            2     BBL
# 3            3    BDMS
# 4            4     BEM
# 5            5   BGRIM
# 6            6      BH
# 7            7     BJC
# 8            8     BTS
# 9            9     CBG
# 10          10    COM7
# 11          11   CPALL
# 12          12     CPF
# 13          13     CPN
# 14          14     CRC
# 15          15   DELTA
# 16          16    DTAC
# 17          17      EA
# 18          18    EGCO
# 19          19  GLOBAL
# 20          20    GPSC
# 21          21    GULF
# 22          22   HMPRO
# 23          23  INTUCH
# 24          24    IRPC
# 25          25     IVL
# 26          26   KBANK
# 27          27     KCE
# 28          28     KTB
# 29          29     KTC
# 30          30      LH
# 31          31    MINT
# 32          32     MTC
# 33          33      OR
# 34          34     OSP
# 35          35     PTT
# 36          36   PTTEP
# 37          37   PTTGC
# 38          38   RATCH
# 39          39   SAWAD
# 40          40     SCB
# 41          41     SCC
# 42          42    SCGP
# 43          43     STA
# 44          44    STGT
# 45          45   TISCO
# 46          46     TOP
# 47          47    TRUE
# 48          48     TTB
# 49          49      TU
